# %% [markdown]
# <a href="https://colab.research.google.com/github/KennePatterson/BSDS/blob/main/notebooks/NGC3198_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ================================================================
# BSDS — Rotation Curve Reproduction Notebook
# Galaxy: NGC 3198
# Author: K. Patterson (Brane-Structured Dark Sector)
# ================================================================

# 0) Setup
# !git clone https://github.com/KennePatterson/BSDS.git
# %cd BSDS/code

# 1) Run the BSDS-SPARC script — generates rotation curve + saves figure
# !python ngc3198_bsds_demo.py

# 2) Display saved figure inside notebook
from IPython.display import Image, display
display(Image(filename="NGC3198_BSDS_SPARC.png"))
# Out:
# Cloning into 'BSDS'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 32 (delta 8), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 193.51 KiB | 1.42 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# /content/BSDS/code
# ...
# Download completed.
# Archive extracted to sparc_data
# Loaded NGC 3198 mass-model data: N = 43
#
# NGC 3198 — BSDS Fit Results
# Data points: 43
# Baryonic mass used (Mb): 6.50e+10 Msun
# k(Mb) = 0.0263
# chi² = 4619.6
# Figure(900x600)
#
# ✅ Figure saved as NGC3198_BSDS_SPARC.png
